# %%
import pandas as pd
import csv

# %%
corona=pd.read_csv('today_corona_edit.csv',encoding='ANSI')

# %%
corona
# Out:
#         국가       확진자        치료중     사망자          완치  치명(%)  완치(%)     발생률  \
# 0       중국     91629      512.0    4636     86481.0      5   94.0      64
# 1       인도  29977861   662521.0  389302  28926038.0      1   97.0   21723
# 2       미국  34419838  5034868.0  617463  28767507.0      2   84.0  103987
# 3    인도네시아   2004445   147728.0   54956   1801761.0      3   90.0    7328
# 4     파키스탄    949838    33452.0   22034    894352.0      2   94.0    4300
# ..     ...       ...        ...     ...         ...    ...    ...     ...
# 86     요르단    747000     6498.0    9671    730831.0      1   98.0   73213
# 87    포르투갈    865806    28657.0   17068    820081.0      2   95.0   84910
# 88  아제르바이잔    335521      959.0    4963    329599.0      2   98.0   33092
# 89     스웨덴   1084636        NaN   14537         NaN      1    NaN  107398
# 90    온두라스    254194   155560.0    6772     91862.0      3   36.0   25664
#
#            인구수     국토면적
# 0   1439323776  9640821
# 1   1380004385  3287263
# ...

# %%
corona['인구밀도'] = (corona['인구수']/corona['국토면적'])

# %%
corona
# Out:
#         국가       확진자        치료중     사망자          완치  치명(%)  완치(%)     발생률  \
# 0       중국     91629      512.0    4636     86481.0      5   94.0      64
# 1       인도  29977861   662521.0  389302  28926038.0      1   97.0   21723
# 2       미국  34419838  5034868.0  617463  28767507.0      2   84.0  103987
# 3    인도네시아   2004445   147728.0   54956   1801761.0      3   90.0    7328
# 4     파키스탄    949838    33452.0   22034    894352.0      2   94.0    4300
# ..     ...       ...        ...     ...         ...    ...    ...     ...
# 86     요르단    747000     6498.0    9671    730831.0      1   98.0   73213
# 87    포르투갈    865806    28657.0   17068    820081.0      2   95.0   84910
# 88  아제르바이잔    335521      959.0    4963    329599.0      2   98.0   33092
# 89     스웨덴   1084636        NaN   14537         NaN      1    NaN  107398
# 90    온두라스    254194   155560.0    6772     91862.0      3   36.0   25664
#
#            인구수     국토면적        인구밀도
# 0   1439323776  9640821  149.294731
# ...

# %%
corona

# %%
df2 = pd.read_csv('./today_corona_edit.csv', encoding='ANSI')
corr=df2.corr(method='pearson')
corr
# Out:
#             확진자       치료중       사망자        완치     치명(%)     완치(%)       발생률  \
# 확진자    1.000000  0.818730  0.926463  0.997564 -0.061699  0.109904  0.390308
# 치료중    0.818730  1.000000  0.814159  0.776890 -0.021864 -0.000551  0.346206
# 사망자    0.926463  0.814159  1.000000  0.928446  0.068280  0.100507  0.444172
# 완치     0.997564  0.776890  0.928446  1.000000 -0.072306  0.120371  0.419379
# 치명(%) -0.061699 -0.021864  0.068280 -0.072306  1.000000 -0.248752 -0.090068
# 완치(%)  0.109904 -0.000551  0.100507  0.120371 -0.248752  1.000000  0.271730
# 발생률    0.390308  0.346206  0.444172  0.419379 -0.090068  0.271730  1.000000
# 인구수    0.508330  0.219260  0.389070  0.532317  0.022548  0.094199 -0.047837
# 국토면적   0.438837  0.436224  0.480154  0.427397  0.044282  0.094283  0.107853
#
#             인구수      국토면적
# 확진자    0.508330  0.438837
# 치료중    0.219260  0.436224
# 사망자    0.389070  0.480154
# 완치     0.532317  0.427397
# 치명(%)  0.022548  0.044282
# 완치(%)  0.094199  0.094283
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
corr = df2.loc[0:5].corr(method = 'pearson')
corr
# Out:
#             확진자       치료중       사망자        완치     치명(%)     완치(%)       발생률  \
# 확진자    1.000000  0.759787  0.927865  0.995513 -0.631211 -0.335871  0.743716
# 치료중    0.759787  1.000000  0.795873  0.695017 -0.304172 -0.823088  0.856407
# 사망자    0.927865  0.795873  1.000000  0.908160 -0.474513 -0.495457  0.924042
# 완치     0.995513  0.695017  0.908160  1.000000 -0.655284 -0.250718  0.694723
# 치명(%) -0.631211 -0.304172 -0.474513 -0.655284  1.000000 -0.021678 -0.250422
# 완치(%) -0.335871 -0.823088 -0.495457 -0.250718 -0.021678  1.000000 -0.724291
# 발생률    0.743716  0.856407  0.924042  0.694723 -0.250422 -0.724291  1.000000
# 인구수    0.055611 -0.286187 -0.183212  0.106262  0.209474  0.603923 -0.423703
# 국토면적   0.351134  0.551265  0.499844  0.306047  0.476402 -0.456900  0.615398
#
#             인구수      국토면적
# 확진자    0.055611  0.351134
# 치료중   -0.286187  0.551265
# 사망자   -0.183212  0.499844
# 완치     0.106262  0.306047
# 치명(%)  0.209474  0.476402
# 완치(%)  0.603923 -0.456900
# ...

# %%
subset = df2.loc[:, ['확진자', '국토면적']]
print(subset.head())
# Out:
#         확진자     국토면적
# 0     91629  9640821
# 1  29977861  3287263
# 2  34419838  9833517
# 3   2004445  1904569
# 4    949838   796095

# %%
df_heatmap=sns.heatmap(corr,cbar = True, annot = True, annot_kws={'size' : 7}, fmt = '.2f', square = True, cmap = 'Blues')

# %%
sns.clustermap(corr, 
               annot = True,      # 실제 값 화면에 나타내기
               cmap = 'RdYlBu_r',  # Red, Yellow, Blue 색상으로 표시
               vmin = -1, vmax = 1, #컬러차트 -1 ~ 1 범위로 표시
              )

# %%
import seaborn as sns

# %%
sns.pairplot(corr,kind="reg")
