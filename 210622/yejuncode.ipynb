# %%
from IPython.display import display, Image
import os, warnings
import re
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time
from selenium.webdriver import ActionChains
from urllib.request import urlopen
driver = webdriver.Chrome('../chromedriver_90')
url = 'https://namu.wiki/w/%EA%B5%AD%EA%B0%80%EB%B3%84%20%EA%B5%AD%ED%86%A0%20%EB%A9%B4%EC%A0%81%20%EC%88%9C%EC%9C%84'
driver.get(url)

# %%
page = driver.page_source
soup = BeautifulSoup(page, 'lxml')
Results = []
Orders = []
Countries = []
Land = []
table = soup.find('table', class_='wiki-table')
table_list = table.findAll('td')
for idx, one in enumerate(table_list):
#     print(idx, ')', one.text.strip().split('\n'))
    Results += one.text.strip().split('\n')
len_R = len(Results)
for i in range(4, len_R+1, 4):
    Orders.append(Results[i])
for i in range(5, len_R+1, 4):
    Countries.append(Results[i])
for i in range(6, len_R+1, 4):
    Land.append(Results[i])
print(len(Orders))
print(len(Countries))
print(len(Land))
# Out:
# 282
# 282
# 282

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
total_list = {'순서':Orders, '나라':Countries, '면적(km^2)':Land}
total_list = pd.DataFrame(total_list)
total_list
# Out:
#                순서                 나라     면적(km^2)
# 0               1                러시아   17,125,407
# 1               ↳             크림 공화국       26,081
# 2               ↳             칼리닌그라드       15,125
# 3               -                 남극   14,200,000
# 4               2                캐나다    9,984,670
# 5               3                 미국    9,833,517
# 6               ↳             푸에르토리코        9,104
# 7               ↳                  괌          544
# 8               ↳           북마리아나 제도          464
# 9               ↳         미국령 버진아일랜드          346
# 10              ↳            미국령 사모아          200
# 11              ↳              웨이크 섬            7
# 12              4                 중국    9,640,821
# 13              ↳                티베트    2,200,000
# 14              ↳              아크사이친       38,850
# 15              ↳                 홍콩        1,106
# 16              ↳                마카오           31
# 17              5                브라질    8,515,770
# 18              6                 호주    7,741,220
# 19              ↳         허드 맥도널드 제도          368
# 20              ↳            크리스마스 섬          135
# 21              ↳               노퍽 섬           34
# 22              ↳             코코스 제도           14
# 23              ↳       애시모어 카르티에 제도            5
# 24              -               유럽연합    4,324,781
# 25              7                 인도    3,287,263
# 26              ↳     잠무 카슈미르 연방 직할지      222,236
# 27              ↳                라다크       86,904
# 28              8              아르헨티나    2,780,400
# 29              9              카자흐스탄    2,724,900
# 30             10                알제리    2,381,741
# 31             11            콩고민주공화국    2,344,858
# 32             12            사우디아라비아    2,149,690
# 33             13                멕시코    1,964,375
# 34             14              인도네시아    1,904,569
# 35             15                 수단    1,861,484
# 36             16                리비아    1,759,540
# 37             17                 이란    1,648,195
# 38              ↳            남아제르바이잔      122,660
# 39             18                 몽골    1,564,116
# 40             19                 페루    1,285,216
# 41             20                 차드    1,284,000
# 42             21                니제르    1,267,000
# 43             22                앙골라    1,246,700
# 44             23                 말리    1,240,192
# 45             24          남아프리카 공화국    1,219,090
# 46              ↳        프린스 에드워드 제도          335
# 47             25               콜롬비아    1,138,914
# 48             26              에티오피아    1,104,300
# 49             27               볼리비아    1,098,581
# 50             28               모리타니    1,030,700
# 51             29                이집트    1,010,408
# 52             30               탄자니아      947,303
# 53             31              나이지리아      923,768
# 54             32              베네수엘라      912,050
# 55             33               나미비아      824,292
# 56             34               모잠비크      801,590
# 57             35               파키스탄      796,095
# 58              ↳           길기트 발티스탄       72,971
# 59              ↳           아자드 카슈미르       13,297
# 60             36                 터키      783,356
# 61             37                 칠레      756,096
# 62              ↳              이스터 섬          163
# 63             38                잠비아      752,618
# 64             39                미얀마      676,578
# 65             40             아프가니스탄      652,230
# 66             41                남수단      644,329
# 67             42                프랑스      640,679
# 68              ↳           프랑스령 기아나       83,534
# 69              ↳             누벨칼레도니       18,576
# 70              ↳               코르시카        8,722
# 71              ↳         프랑스령 폴리네시아        3,521
# 72              ↳               레위니옹        2,511
# 73              ↳               과들루프        1,628
# 74              ↳              마르티니크        1,128
# 75              ↳           생피에르 미클롱          242
# 76              ↳            왈리스 푸투나          142
# 77              ↳               몬트세랫          102
# 78              ↳               생마르탱           53
# 79              ↳             생바르텔레미           25
# 80             43               소말리아      637,657
# 81             44          중앙아프리카공화국      622,984
# 82             45              우크라이나      603,628
# 83             46             마다가스카르      587,041
# 84             47               보츠와나      581,730
# 85             48                 케냐      580,367
# 86             49                 예멘      527,968
# 87             50                 태국      513,120
# 88             51                스페인      505,990
# 89              ↳            카나리아 제도           34
# 90              ↳                세우타           19
# 91              ↳                멜리야           12
# 92             52            투르크메니스탄      491,210
# 93             53                카메룬      475,440
# 94             54             파푸아뉴기니      462,840
# 95             55                스웨덴      450,295
# 96             56             우즈베키스탄      447,400
# 97              ↳             카라칼팍스탄      166,600
# 98             57                모로코      446,550
# 99              ↳               서사하라       82,500
# 100            58                이라크      438,317
# 101            59               파라과이      406,752
# 102            60               짐바브웨      390,757
# 103            61                 일본      377,975
# 104            62                 독일      357,022
# 105            63             콩고 공화국      342,000
# 106            64                핀란드      338,145
# 107             ↳             올란드 제도        1,580
# 108            65                베트남      331,210
# 109            66              말레이시아      329,847
# 110            67               노르웨이      323,802
# 111             ↳            스발바르 제도       61,022
# 112            68             코트디부아르      322,463
# 113            69                폴란드      312,685
# 114            70                 오만      309,500
# 115            71               이탈리아      301,340
# 116            72                필리핀      300,000
# 117            73               에콰도르      283,561
# 118            74             부르키나파소      274,200
# 119            75               뉴질랜드      268,838
# 120             ↳              채텀 제도          966
# 121             ↳                니우에          261
# 122             ↳               쿡 제도          236
# 123             ↳               토켈라우           10
# 124            76                 가봉      267,667
# 125            77                 기니      245,857
# 126            78                 영국      243,610
# 127             ↳            포클랜드 제도       12,173
# 128             ↳  사우스조지아 사우스샌드위치 제도        3,903
# 129             ↳        터크스 케이커스 제도          616
# 130             ↳                맨 섬          572
# 131             ↳             케이맨 제도          264
# 132             ↳         아크로티리 데켈리아          254
# 133             ↳            트리스탄다쿠냐          207
# 134             ↳         영국령 버진아일랜드          153
# 135             ↳             세인트헬레나          121
# 136             ↳               저지 섬          118
# 137             ↳                앵귈라           91
# 138             ↳              어센션 섬           88
# 139             ↳               건지 섬           78
# 140             ↳         영국령 인도양 지역           60
# 141             ↳             차고스 제도           56
# 142             ↳                버뮤다           53
# 143             ↳             핏케언 제도           47
# 144             ↳               지브롤터            7
# 145             ↳                올더니            7
# 146             ↳                 사크            7
# 147             ↳               지브롤터            7
# 148            79                우간다      241,038
# 149            80                 가나      238,533
# 150            81               루마니아      238,391
# 151            82                라오스      237,955
# 152             -                한반도      223,516
# 153            83               가이아나      214,969
# 154            84               벨라루스      207,600
# 155            85             키르기스스탄      199,951
# 156            86                세네갈      196,722
# 157            87                시리아      185,180
# 158             ↳                로자바       50,000
# 159            88               캄보디아      181,035
# 160            89               우루과이      176,215
# 161            90                수리남      163,820
# 162            91                튀니지      163,610
# 163            92                 네팔      147,516
# 164            93              방글라데시      143,998
# 165            94              타지키스탄      143,100
# 166            95                그리스      131,957
# 167            96               니카라과      130,370
# 168            97                 북한      120,540
# 169            98                말라위      118,484
# 170            99              에리트레아      117,600
# 171           100                 베냉      112,622
# 172           101               온두라스      112,492
# 173           102              라이베리아      111,369
# 174           103               불가리아      110,993
# 175           104                 쿠바      109,884
# 176           105               과테말라      108,889
# 177           106              아이슬란드      102,775
# 178           107               대한민국      100,412
# 179           108                헝가리       93,028
# 180           109               포르투갈       92,090
# 181             ↳            아소르스 제도        2,351
# 182             ↳            마데이라 제도          801
# 183           110                요르단       89,342
# 184           111             아제르바이잔       86,600
# 185           112              오스트리아       83,871
# 186           113             아랍에미리트       83,600
# 187           114                 체코       78,867
# 188           115               세르비아       77,474
# 189           116                파나마       75,420
# 190           117              시에라리온       71,740
# 191           118               아일랜드       70,273
# 192           119                조지아       69,700
# 193             ↳              남오세티야        3,900
# 194             ↳               아자리야        2,900
# 195           120               스리랑카       65,610
# 196           121              리투아니아       65,300
# 197           122               라트비아       64,559
# 198           123                 토고       56,785
# 199           124              크로아티아       56,594
# 200           125        보스니아 헤르체고비나       51,197
# 201           126              코스타리카       51,100
# 202           127              슬로바키아       49,035
# 203           128           도미니카 공화국       48,670
# 204           129              에스토니아       45,228
# 205           130                덴마크       43,094
# 206             ↳               그린란드    2,166,086
# 207             ↳              페로 제도        1,399
# 208           131               네덜란드       41,543
# 209             ↳                퀴라소          444
# 210             ↳           카리브 네덜란드          328
# 211             ↳                아루바          178
# 212             ↳              신트마르턴           37
# 213           132                스위스       41,277
# 214           133                 부탄       38,394
# 215           134              기니비사우       36,125
# 216           135                 대만       36,197
# 217           136                몰도바       33,851
# 218             ↳           트란스니스트리아        4,163
# 219             ↳              가가우지아        1,832
# 220           137                벨기에       30,528
# 221           138                레소토       30,355
# 222           139              아르메니아       29,743
# 223           140             솔로몬 제도       28,896
# 224           141               알바니아       28,748
# 225           142              적도 기니       28,051
# 226           143                부룬디       27,834
# 227           144                아이티       27,750
# 228           145                르완다       26,338
# 229           146             북마케도니아       25,713
# 230           147                지부티       23,200
# 231           148                벨리즈       22,966
# 232           149               이스라엘       22,072
# 233           150              엘살바도르       21,041
# 234           151              슬로베니아       20,273
# 235           152                 피지       18,274
# 236           153               쿠웨이트       17,818
# 237           154              에스와티니       17,364
# 238           155               동티모르       14,874
# 239           156                바하마       13,943
# 240           157              몬테네그로       13,812
# 241           158               바누아투       12,189
# 242           159                카타르       11,586
# 243           160                감비아       11,295
# 244           161               자메이카       10,991
# 245           162                코소보       10,887
# 246           163                레바논       10,452
# 247           164               키프로스        9,251
# 248             ↳       북키프로스 터키 공화국        3,355
# 249           165          팔레스타인[15]        6,020
# 250          브루나이              5,765
# 251     트리니다드 토바고              5,130
# 252         카보베르데              4,033
# 253           사모아              2,831
# 254         룩셈부르크              2,586
# 255           코모로              2,235
# 256          모리셔스              2,040
# 257      상투메 프린시페                964
# 258          키리바시                811
# 259       도미니카 연방                751
# 260            통가                747
# 261           바레인                741
# 262     미크로네시아 연방                702
# 263          싱가포르                697
# 264       세인트 루시아                616
# 265           안도라                468
# 266           팔라우                459
# 267           세이셸                455      아프리카 최소
# 268       앤티가 바부다                443
# 269         바베이도스                430
# 270  세인트 빈센트 그레나딘                389
# 271          그레나다                344
# 272            몰타                316     유럽 연합 최소
# 273           몰디브                298       아시아 최소
# 274    세인트 키츠 네비스                261      아메리카 최소
# 275         마셜 제도                181
# 276        리히텐슈타인                160
# 277          산마리노                 61
# 278           투발루                 26
# 279           나우루                 21     공화국 중 최소
# 280           모나코                  2  유엔 회원국 중 최소
# 281           바티칸               0.44        세계 최소
