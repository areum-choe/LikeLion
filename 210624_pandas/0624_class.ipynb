# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5], 'o') # '-' 선 : 기본값
plt.show()

# %%
print(matplotlib.__version__)
# Out:
# 3.3.2

# %%
x = range(0, 100)
y = range(0, 200,2)
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### fmt의 파라미터를 다음과 같이 사용
# * marker | line | color

# %%
y = np.array([3, 8, 1, 10])
plt.plot(y, '^:b')
plt.show()

# %% [markdown]
# ### 마커 사이즈

# %%
y = np.array([3, 3, 1, 20, 10])
plt.plot(y , marker = 'o', ms=15)
plt.show()

# %%
y = np.array([3, 3, 1, 20, 10])
plt.plot(y , marker = 'o', ms=15, mec = 'r')
plt.show()

# %%
y = np.array([3, 3, 1, 20, 10])
plt.plot(y , marker = 'o', ms=15, mfc = 'r')
plt.show()

# %%
### 선 굵기
y = np.array([3, 8, 1, 12, 5])
plt.plot(y, linewidth = '12.5')

# %% [markdown]
# ### 03 여러 개의 그래프 그리기
# ### 한 화면에 여러개의 그래프를 그리기 위해서는
# *  (1) figure 함수를 통해 Figure 객체를 만든다.
# *  (2) add_subplot 메서드를 통해 그리려는 그래프 개수만큼 subplot를 만들면 된다.

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
plt.show()

# %% [markdown]
# ### figure()함수를 통해 3x3으로 만들어보기
# * add_subplot을 통해 추가

# %%
fig = plt.figure(figsize=(12,15))
ax1 = fig.add_subplot(3,3,1)
ax2 = fig.add_subplot(3,3,2)
ax3 = fig.add_subplot(3,3,3)
ax4 = fig.add_subplot(3,3,4) 
ax5 = fig.add_subplot(3,3,5) 
ax6 = fig.add_subplot(3,3,6)
ax7 = fig.add_subplot(3,3,7) 
ax8 = fig.add_subplot(3,3,8) 
ax9 = fig.add_subplot(3,3,9)
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,3,1) # 1행 3열 의 것중에 첫번째
ax2 = fig.add_subplot(1,3,2) # 1행 3열 의 것중에 두번째
ax3 = fig.add_subplot(1,3,3) # 1행 3열 의 것중에 두번째
plt.show()

# %%
### plot, bar 그래프 그리기
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
x=range(0,100)
y=[v*v for v in x]
ax1.plot(x,y)
ax2.bar(x,y)
plt.show()

# %% [markdown]
# ### sin,cos그래프 그려보기

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0.0, 2 * np.pi, 0.1)
sin_y = np.sin(x)
cos_y = np.cos(x)
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)
ax1.plot(x, sin_y, 'b--')
ax2.plot(x, cos_y, 'r--')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0.0, 2 * np.pi, 0.1)
sin_y = np.sin(x)
cos_y = np.cos(x)
tan_y=np.tan(x)
tanh_y=np.tanh(x)
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)
ax1.plot(x, sin_y, 'b--')
ax2.plot(x, cos_y, 'r--')
ax3.plot(x, tan_y, 'b--')
ax4.plot(x, tanh_y, 'r--')

plt.show()

# %% [markdown]
# ### 04 범례 표시 - 기본

# %%
x = np.arange(10)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.plot(x, 2*x, label='y = %ix' % 2)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(3,3,1)
plt.plot(x,1*x, label='y = %ix'%1)
plt.legend(loc='upper left') # 2

# %% [markdown]
# ### 타이틀과 레이블

# %%
import os, warnings
warnings.filterwarnings(action='ignore')

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.title("스포츠 시청 데이터")
plt.xlabel("평균 혈압")
plt.ylabel("칼로리")
# Out:
# Text(0, 0.5, '칼로리')

# %%
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
import platform

# %%
path = "C:/Windows/Fonts/malgun.ttf"
if platform.system() == "Windows":
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system()=="Darwin":
    rc('font', family='AppleGothic')
else:
    print("Unknown System")
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.plot(x, y)
plt.title("스포츠 시청 데이터")
plt.xlabel("평균 혈압")
plt.ylabel("칼로리")
# Out:
# Text(0, 0.5, '칼로리')

# %% [markdown]
# ### grid

# %%
x = np.array([70, 75, 80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([220, 240, 260, 280, 300, 320, 340, 360, 380, 400, 420, 440])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.plot(x, y)

# %% [markdown]
# ### 07 Super Title
# * 전체 이미지의 상위 타이틀을 subtitle()를 이용하여 제목을 추가할 수 있다.

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")
#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")
plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# ### Scatter plot

# %%
x = np.array([51,71,18,17,21,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color='hotpink')
x = np.array([511,711,118,17,21,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color='#88c999')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randint(10, size=10)
print(len(x), type(x))
y = np.random.randint(80,100, size=10)
print(len(y), type(y))
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70])
plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar() # colormap 을 포함할 수 있다.
plt.show()
# Out:
# 10 <class 'numpy.ndarray'>
# 10 <class 'numpy.ndarray'>

# %% [markdown]
# ### 사용가능한 colorMaps
# * https://www.w3schools.com/python/matplotlib_scatter.asp
# * (https://www.w3schools.com/python/matplotlib_scatter.asp)

# %% [markdown]
# ### Alpha (투명도)

# %%
x = np.random.randint(10, size=10)
y = np.random.randint(80,100, size=10)
sizes = np.random.randint(20,800, size=10)
colors = np.random.randint(0,100, size=10)
plt.scatter(x, y, s=sizes, alpha=0.5)

# %% [markdown]
# ### barplot

# %%
x = np.array(['A', 'B', 'C', 'D'])
y = np.array([30,20,40,90])
plt.bar(x, y)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### Horizontal Bars

# %%
x = np.array(['A', 'B', 'C', 'D'])
y = np.array([30,20,40,90])
plt.barh(x, y)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### pie chart

# %%
y= np.array([30,20,35,10,5])
plt.figure(figsize=(10,10))
plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x2320ec754c0>,
#   <matplotlib.patches.Wedge at 0x2320ec75e50>,
#   <matplotlib.patches.Wedge at 0x2320eb6e040>,
#   <matplotlib.patches.Wedge at 0x2320eb6ed60>,
#   <matplotlib.patches.Wedge at 0x2320eb899a0>],
#  [Text(0.6465637441936395, 0.8899187180267095, ''),
#   Text(-0.8899187482945419, 0.6465637025335369, ''),
#   Text(-0.49938947630209474, -0.9801072140121813, ''),
#   Text(0.8899187331606258, -0.6465637233635886, ''),
#   Text(1.0864571863351944, -0.1720778377961938, '')])

# %%
plt.figure(figsize=(10,10))
y = np.array([30,20,35,10, 5])
addlbl = ['사과', '바나나', '딸기', '수박', '오렌지']
plt.pie(y, labels=addlbl)
# Out:
# ([<matplotlib.patches.Wedge at 0x2320e890dc0>,
#   <matplotlib.patches.Wedge at 0x2320e8cd2e0>,
#   <matplotlib.patches.Wedge at 0x2320e8cd760>,
#   <matplotlib.patches.Wedge at 0x2320e8cdbe0>,
#   <matplotlib.patches.Wedge at 0x2320ec900a0>],
#  [Text(0.6465637441936395, 0.8899187180267095, '사과'),
#   Text(-0.8899187482945419, 0.6465637025335369, '바나나'),
#   Text(-0.49938947630209474, -0.9801072140121813, '딸기'),
#   Text(0.8899187331606258, -0.6465637233635886, '수박'),
#   Text(1.0864571863351944, -0.1720778377961938, '오렌지')])

# %%
y= np.array([30,20,35,10,5])
addlbl= ['사과', '바나나', '딸기', '수박', '오렌지']
plt.pie(y, labels= addlbl, startangle= 90)
# Out:
# ([<matplotlib.patches.Wedge at 0x2320eb3a8b0>,
#   <matplotlib.patches.Wedge at 0x2320eb3adc0>,
#   <matplotlib.patches.Wedge at 0x2320eb17280>,
#   <matplotlib.patches.Wedge at 0x2320eb17700>,
#   <matplotlib.patches.Wedge at 0x2320eb17b80>],
#  [Text(-0.8899187180267095, 0.6465637441936395, '사과'),
#   Text(-0.6465637025335373, -0.8899187482945414, '바나나'),
#   Text(0.9801072140121813, -0.4993894763020948, '딸기'),
#   Text(0.6465637233635887, 0.8899187331606258, '수박'),
#   Text(0.17207783779619384, 1.0864571863351942, '오렌지')])

# %%
y = np.array([30,20,35,10, 5])
addlbl = ['사과', '바나나', '딸기', '수박', '오렌지']
myexplode = [0.2, 0, 0, 0, 0.3]
plt.pie(y, labels = addlbl, explode = myexplode)
# Out:
# ([<matplotlib.patches.Wedge at 0x2320ed946a0>,
#   <matplotlib.patches.Wedge at 0x2320ed94bb0>,
#   <matplotlib.patches.Wedge at 0x2320ed94fd0>,
#   <matplotlib.patches.Wedge at 0x2320ed914f0>,
#   <matplotlib.patches.Wedge at 0x2320ed91970>],
#  [Text(0.764120788592483, 1.051722121304293, '사과'),
#   Text(-0.8899187482945419, 0.6465637025335369, '바나나'),
#   Text(-0.49938947630209474, -0.9801072140121813, '딸기'),
#   Text(0.8899187331606258, -0.6465637233635886, '수박'),
#   Text(1.3827636916993382, -0.21900815719515573, '오렌지')])

# %%
y = np.array([30,20,35,10, 5])
addlbl = ['사과', '바나나', '딸기', '수박', '오렌지']
myexplode = [0.2, 0, 0, 0, 0.3]
plt.pie(y, labels = addlbl, explode = myexplode)
plt.legend()
